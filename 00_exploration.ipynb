# %%
dbutils.library.restartPython()

# %%
pip install Pdfplumber

# %%
import os
import pdfplumber

# %%
# %pip install --upgrade typing_extensions>=4.13.0

# %%
pip install pypdf

# %%
dbutils.library.restartPython()

# %%
from langchain_community.document_loaders import PyPDFLoader
