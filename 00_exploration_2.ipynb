# %%
import os
import pdfplumber

# %%
pdf_file = 'MediStar_Healthcare_Policy_Detailed_Insurance.pdf'
pdf_volume_path = '/Volumes/llm/rag/healthcare_docs'
pdf_path = os.path.join(pdf_volume_path, pdf_file)
with pdfplumber.open(pdf_path) as pdf:
    for page in pdf.pages:
        
        print(page.extract_text())
